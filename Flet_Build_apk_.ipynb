# %% [markdown]
# <a href="https://colab.research.google.com/github/flet-build-to-system/drive-colab/blob/main/Flet_Build_apk_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install ninja-build

# %%
# !sudo apt-get install google-chrome-stable

# %%
# !sudo apt-get install libgtk-3-dev

# %%
# !apt-get install -y openjdk-18-jdk

# %%
# !git config --global --add safe.directory /root/flutter/3.29.2

# %%
# !pip install flet[all]

# %%
# !flet create ReorderableListView

# %%
pip install flashlight==0.1.1

# %%
# !flet build apk ReorderableListView --no-android-splash

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# @title
# !flet build aab ReorderableListView --no-android-splash

# %%
# !flet build web ReorderableListView --no-android-splash

# %%
import kagglehub
path = kagglehub.dataset_download("shivamb/netflix-shows")

# %%
# !python -m http.server --directory build/web

# %%
# !git config --global --add safe.directory /root/flutter/3.29.2/

# %%
# !flet build aab ReorderableListView --no-android-splash

# %%
# !sudo apt install python3-dev build-essential

# %%
# !pip install --upgrade httptools
